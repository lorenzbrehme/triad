# %%
import json
with open('../final_hotpot.json') as f:
    final_data = json.load(f)['data']
counter_binary_comparasion = 0
counter_comparasion = 0
counter_binary_intersection = 0
counter_intersection = 0
counter_binario_composition = 0
counter_composition = 0
counter = 1

def sufficent_Context_checker(list):
    for item in list:
        if item == True:
            return False
    return True


for item in final_data:
        if item['quality_validation']['accepted'] == True and sufficent_Context_checker(item['sufficient_context_flags']):
            if item['type'] == 'comparison_question' and item['binary'] == True:
                if counter_binary_comparasion < 16:
                    counter_binary_comparasion += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'comparison_question' and item['binary'] == False:
                if counter_comparasion < 16:
                    counter_comparasion += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'intersection_question' and item['binary'] == True:
                if counter_binary_intersection < 17:
                    counter_binary_intersection += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'intersection_question' and item['binary'] == False:
                if counter_intersection < 17:
                    counter_intersection += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'attribute_composition' and item['binary'] == True:
                if counter_binario_composition < 17:
                    counter_binario_composition += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'attribute_composition' and item['binary'] == False:
                if counter_composition < 17:
                    item['id'] = counter
                    final_data.append(item)
                    counter_composition += 1
                    counter += 1
with open('./hotpot_sample.json', 'w') as f:
    json.dump(final_data, f, indent=4)

# %%
import json
with open('../final_musique.json') as f:
    final_data = json.load(f)['data']

    
counter_binary_comparasion = 0
counter_comparasion = 0
counter_binary_intersection = 0
counter_intersection = 0
counter_binario_composition = 0
counter_composition = 0
counter = 1
def sufficent_Context_checker(list):
    for item in list:
        if item == True:
            return False
    return True


for item in final_data:
    
    
        
        if item['quality_validation']['accepted'] == True and sufficent_Context_checker(item['sufficient_context_flags']):
            if item['type'] == 'comparison_question' and item['binary'] == True:
                if counter_binary_comparasion < 16:
                    counter_binary_comparasion += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'comparison_question' and item['binary'] == False:
                if counter_comparasion < 16:
                    counter_comparasion += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'intersection_question' and item['binary'] == True:
                if counter_binary_intersection < 17:
                    counter_binary_intersection += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'intersection_question' and item['binary'] == False:
                if counter_intersection < 17:
                    counter_intersection += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'attribute_composition' and item['binary'] == True:
                if counter_binario_composition < 17:
                    counter_binario_composition += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
            elif item['type'] == 'attribute_composition' and item['binary'] == False:
                if counter_composition < 17:
                    counter_composition += 1
                    item['id'] = counter
                    final_data.append(item)
                    counter += 1
with open('./musique_sample.json', 'w') as f:
    json.dump(final_data, f, indent=4)
